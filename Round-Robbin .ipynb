# %%
def findWaitingTime(processes, n, bt,wt, quantum,pl):
    
    rem_bt = [0] * n
    for i in range(n):
        rem_bt[i] = bt[i]
    t =0
    while(1):
        done = True
        for i in range(n):
            if (rem_bt[i] > 0) :
                done = False
                if (rem_bt[i] > quantum) : 
                    print(t)

                    print(quantum)
                    pl.append({i+1:(t,quantum)})
                    print("Running Process "+ str(i+1)+ " From time : "+str(t) +" to " + str(t+quantum))
                    t += quantum
                    rem_bt[i] -= quantum
                else:
                    pl.append({i+1:(t, rem_bt[i])})
                    print("Running Process "+ str(i+1)+ " From time : "+str(t)+" to "+ str(t + rem_bt[i]))
                    t = t + rem_bt[i]
                    wt[i] = t - bt[i]
                    rem_bt[i] = 0
                    print("<---------------------- Complete Process : "+ str(i+1)+" ---------------------->")
        if (done == True):
            break
def findTurnAroundTime(processes, n, bt, wt, tat): 
    for i in range(n):
        tat[i] = bt[i] + wt[i]
def findavgTime(processes, n, bt, quantum,pl):
    wt = [0] * n
    tat = [0] * n
    findWaitingTime(processes, n, bt,
                         wt, quantum,pl)
    findTurnAroundTime(processes, n, bt,
                                wt, tat)
    print("\n-------------------------------------------------\n")
    print("Processes    Burst Time     Waiting",
                     "Time    Turn-Around Time")
    total_wt = 0
    total_tat = 0
    for i in range(n):
        total_wt = total_wt + wt[i]
        total_tat = total_tat + tat[i]
        print(" ", i + 1, "\t\t", bt[i],
              "\t\t", wt[i], "\t\t", tat[i])
    print("\nAverage waiting time = %.5f "%(total_wt /n) )
    print("Average turn around time = %.5f "% (total_tat / n))
    print("\b")
    print(pl)
proc = []
burst_time = []
quantum = int(input("Enter The Size of Quantum "))
n = int(input("Enter The Number of Processes "))
total=0;
for a in range(n):
  proc.append(a)
  b = int(input("Enter The Burst Time of "+str(a+1) +" = "))
  total =total+b;
  burst_time.append(b)
print("\n-------------------------------------------------\n\n\n")
plotgraph= []
# print(total)
findavgTime(proc, n, burst_time, quantum,plotgraph)
# Out:
# Enter The Size of Quantum 3
# Enter The Number of Processes 2
# Enter The Burst Time of 1 = 4
# Enter The Burst Time of 2 = 2
#
# -------------------------------------------------
#
#
#
# 0
# 3
# Running Process 1 From time : 0 to 3
# Running Process 2 From time : 3 to 5
# <---------------------- Complete Process : 2 ---------------------->
# Running Process 1 From time : 5 to 6
# <---------------------- Complete Process : 1 ---------------------->
#
# -------------------------------------------------
#
# Processes    Burst Time     Waiting Time    Turn-Around Time
#   1 		 4 		 2 		 6
#   2 		 2 		 3 		 5
#
# Average waiting time = 2.50000
# Average turn around time = 5.50000
#
# [{1: (0, 3)}, {2: (3, 2)}, {1: (5, 1)}]
